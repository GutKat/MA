# %%
import MDAnalysis
from MDAnalysis.analysis.hydrogenbonds.hbond_analysis import HydrogenBondAnalysis as HBA
import math
import os
import sys
import statistics
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
from pylab import *

# %%
import varnaapi
varnaapi.set_VARNA('/home/mescalin/kgutenbrunner/Downloads/VARNAv3-93.jar')

# %%
from varnaapi import Structure
seq =  'UGUCAGGCCCUCGUUCAGAGGCCACGUCUAGAGCAAAAAGACGUGCAGCCUGUUUUUUU'
ss =  r'{{.(((((((((.....)))).(((((((.[[[.....)))))))}})))))..]]]..'


v = varnaapi.Structure(sequence=seq, structure=ss)
# .update(bpStyle='simple', drawBackbone=True, bp='#006400', fillBases=True, spaceBetweenBases=1, resolution=2)
style_bp_triple = varnaapi.param.BasesStyle(fill="red")
style_pk1 = varnaapi.param.BasesStyle(fill="blue")
style_pk2 = varnaapi.param.BasesStyle(fill="green")

v.add_bases_style(style_bp_triple, [3, 44, 24])
v.add_bases_style(style_pk1, [1, 2, 46, 47])
v.add_bases_style(style_pk2, [33,32, 31, 55,56,57])

v.update(bpStyle='simple', drawBackbone=True, bp='#006400', fillBases=True, spaceBetweenBases=1, resolution=2)
v.add_aux_BP(3, 44, color="red")
v.add_aux_BP(3, 24, color="red")
v.add_aux_BP(44, 24, color="red")
v.show()
# Out:
# Output file: /tmp/tmpijnhohxw.svg
# JupyterSvgImage(svg='<?xml version="1.0" encoding="UTF-8"?>\n<!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" \n"http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">\n\n<svg width="282px" height="320.28446270334314px" version="1.1" viewBox="0 0 300 400" \nxmlns="http://www.w3.org/2000/svg">\n<line x1="74.15275452701758" y1="307.78446270334314" x2="81.65275452701758" y2="307.78446270334314" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="91.65275452701758" y1="307.78446270334314" x2="99.15275452701758" y2="307.78446270334314" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="109.15275452701758" y1="307.78446270334314" x2="116.65275452701758" y2="307.78446270334314" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="121.65275452701758" y1="302.78446270334314" x2="121.65275452701758" y2="292.78446270334314" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="121.65275452701758" y1="282.78446270334314" x2="121.65275452701758" y2="272.78446270334314" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="121.65275452701758" y1="262.78446270334314" x2="121.65275452701758" y2="252.78446270334314" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="121.65275452701758" y1="242.78446270334314" x2="121.65275452701758" y2="232.78446270334314" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="118.11722062108484" y1="224.2489287974104" x2="112.56655433258521" y2="218.69826250891077" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="104.03102042665247" y1="215.16272860297804" x2="94.03102042665246" y2="215.16272860297804" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="84.03102042665246" y1="215.16272860297804" x2="74.03102042665247" y2="215.16272860297804" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="64.03102042665247" y1="215.16272860297804" x2="54.03102042665245" y2="215.16272860297804" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="44.405872155512796" y1="217.0622031276753" x2="37.46812839813752" y2="219.91142368309866" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="28.227053007525193" y1="219.88912381216136" x2="21.30314102021712" y2="217.00645334739107" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="14.776583877638483" y1="210.4641278033754" x2="11.910630023105956" y2="203.53327975135917" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="11.910630023105956" y1="194.2921774545969" x2="14.776583877638483" y2="187.3613294025807" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="21.30314102021711" y1="180.81900385856497" x2="28.22705300752517" y2="177.93633339379468" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="37.46812839813749" y1="177.91403352285735" x2="44.4058721555128" y2="180.76325407828077" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="54.03102042665245" y1="182.66272860297804" x2="64.03102042665245" y2="182.66272860297804" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="74.03102042665245" y1="182.66272860297804" x2="84.03102042665246" y2="182.66272860297804" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="94.03102042665246" y1="182.66272860297804" x2="104.03102042665246" y2="182.66272860297804" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="112.5373867479885" y1="179.09826577940976" x2="117.67417279243028" y2="173.8763690321639" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="126.00660742109034" y1="169.0045941980019" x2="133.07674158811568" y2="167.08939724585062" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="140.35522955878028" y1="161.42483406108065" x2="145.2600688854614" y2="152.7103317127281" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="150.1649082121425" y1="143.99582936437554" x2="155.0697475388236" y2="135.28132701602294" stroke="rgb(35%, 35%, 35%)" stroke-width="1.0" />\n<line x1="159.9745868655047" y1="126.56682466767037" x2="164.87942619218 ...

# %% [markdown]
# # functions

# %%
def get_pairwise_distances(dcd_file, pdb_file, movie_skip):
    u = MDAnalysis.Universe(pdb_file, dcd_file)
    selection = u.select_atoms("record_type ATOM")
    pairwise_distances = []

    for t, ts in enumerate(u.trajectory):
        if t % movie_skip != 0:
            continuev.add_aux_BP(14, 20, edge5="s", color="#FF00FF")
        positions = selection.center(None, compound="residues")

        for i, pos_i in enumerate(positions):
            pairwise_distances[t].append([])
            for j, pos_j in enumerate(positions):
                if i > j:
                    pairwise_distances[t][i].append(pairwise_distances[t][j][i])
                else:
                    pairwise_distances[t][i].append(np.linalg.norm(pos_j-pos_i))

    return pairwise_distances

# %%
def get_bp_distance(dcd_file, pdb_file, movie_skip, bp):
    u = MDAnalysis.Universe(pdb_file, dcd_file)
    selection = u.select_atoms("record_type ATOM")
    distances = []

    for t, ts in enumerate(u.trajectory):
        if t % movie_skip != 0:
            continue
        t = int(t/movie_skip)
        positions = selection.center(None, compound="residues")
        pos_i = positions[bp[0]]
        pos_j = positions[bp[1]]
        distances.append(np.linalg.norm(pos_j-pos_i))

    return distances

# %%
def remove_comments(lines):
    cleaned = [line for line in lines if line[0].isnumeric()]
    return cleaned

def get_steps(foldername, gradient):
    outLines = []
    inF = open(f"{foldername}/out{gradient}_1_1.txt", 'r')

    outLines.append("Step ")
    lines = remove_comments(inF.readlines())

    start = int(lines[0][0:lines[0].find(',')])
    step = int(lines[1][0:lines[1].find(',')]) - int(lines[0][0:lines[0].find(',')])
    inF.close()

    return start, step


def calculate_endforce(foldername, distances, ):
    end_force = ((len(distances)*movie_skip*step_interval*2)/1000000000) * gradient
    return end_force

# %% [markdown]
# # folder

# %%
base_folder = '/scr/aldea/kgutenbrunner/working/MD/MBFV/designs/design_07/'
foldername = os.path.join(base_folder, 'run1000_1/')
gradient = 1000

movie_skip = 50

basedir = os.getcwd()

dcd_files = [foldername + i for i in os.listdir(foldername) if i.endswith('.dcd')]
pdb_file = base_folder + 'init.pdb'



step_start, step_interval = get_steps(foldername, gradient)

# %% [markdown]
# # plot distances

# %%
distances_file = os.path.join(base_folder, 'pk1_distance.txt')

distances_pk1 = {}
with open(distances_file, 'r') as f:
    distances = None
    simulation = None
    for line in f.readlines():
        if not line.startswith('>'):
            distances.append(float(line))
        else:
            distances_pk1[simulation] = distances
            simulation=int(line[1:-1]) +1
            distances=[]

del distances_pk1[None]
distances_pk1[simulation] = distances
force=line

# %%
for key,distance in distances_pk1.items():
    end_force = ((len(distance)*movie_skip*step_interval*2)/1000000000) * gradient
    plt.plot(np.linspace(start=0, stop=end_force, num=len(distance[1:])), distance[1:], label=key)
    #plt.plot(np.linspace(start=0, stop=end_force, num=len(distances[1:])), distances[1:], label=key)

plt.legend(title='Simulation', loc=4)
plt.title(f'Pseudo Knot 1 Distance during MD simulations', fontsize=14)
plt.xlabel('Force [pN]')
plt.ylabel(r'Distance [$\AA$]')

save_under = os.path.join(base_folder, 'pk1_distance_comb.png')
print(save_under)
plt.savefig(save_under)
# Out:
# /scr/aldea/kgutenbrunner/working/MD/MBFV/designs/design_03/pk1_distance_comb.png

# %%
distances_file = os.path.join(base_folder, 'distances.txt')

distances_analysis = {}
with open(distances_file, 'r') as f:
    distances = None
    simulation = None
    for line in f.readlines():
        if not line.startswith('>'):
            distances.append(float(line))
        else:
            distances_analysis[simulation] = distances
            simulation=int(line[1:-1]) +1
            distances=[]

del distances_analysis[None]
distances_analysis[simulation] = distances
force=line

# %%
for key,distance in distances_analysis.items():
    end_force = ((len(distance)*step_interval*2)/1000000000) * gradient
    plt.plot(np.linspace(start=0, stop=end_force, num=len(distance[1:])), distance[1:], label=key)

plt.legend(title='Simulation', loc=4)
plt.title(f'5\' end distance during MD Simulations', fontsize=14)
plt.xlabel('Force [pN]')
plt.ylabel(r'Distance [$\AA$]')

save_under = os.path.join(base_folder, 'pk1_distance_comb.png')
print(save_under)
#plt.savefig(save_under)
# Out:
# /scr/aldea/kgutenbrunner/working/MD/MBFV/designs/design_03/pk1_distance_comb.png

# %% [markdown]
# # calculate distances

# %%
pk2_distances = []
pk1_distances = []


pk1_bp = [0, 46]
pk2_bp = [31, 55]
for dcd in dcd_files:
    pk1_distances.append(get_bp_distance(dcd, pdb_file, movie_skip, pk1_bp))
    pk2_distances.append(get_bp_distance(dcd, pdb_file, movie_skip, pk2_bp))
# Out:
# /home/mescalin/kgutenbrunner/.conda/envs/MDanalysis/lib/python3.12/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"

# %%
with open('pk1_distance.txt', 'w') as f:
    for i, distances in enumerate(pk1_distances):
        f.write(f'>{i}\n')
        for dis in distances:
            f.write(str(dis) + '\n')

# %%
with open('pk2_distance.txt', 'w') as f:
    for i, distances in enumerate(pk2_distances):
        f.write(f'>{i}\n')
        for dis in distances:
            f.write(str(dis) + '\n')

# %%
def triangle_area_3d(point1, point2, point3):
    # Convert points to numpy arrays for easy vector operations
    p1 = np.array(point1)
    p2 = np.array(point2)
    p3 = np.array(point3)
    
    # Calculate the vectors representing two sides of the triangle
    v1 = p2 - p1
    v2 = p3 - p1
    
    # Calculate the cross product of the two vectors
    cross_product = np.cross(v1, v2)
    
    # Calculate the magnitude of the cross product vector
    area = np.linalg.norm(cross_product) / 2
    
    return area

# %%
def get_area(dcd_file, pdb_file, movie_skip, bp):
    u = MDAnalysis.Universe(pdb_file, dcd_file)
    selection = u.select_atoms("record_type ATOM")
    areas = []

    for t, ts in enumerate(u.trajectory):
        if t % movie_skip != 0:
            continue
        t = int(t/movie_skip)
        positions = selection.center(None, compound="residues")
        pos_i = positions[bp[0]]
        pos_j = positions[bp[1]]
        pos_k = positions[bp[2]]
        areas.append(triangle_area_3d(pos_i, pos_j, pos_k))

    return areas

# %%
bp_triplet = [2, 10, 27]
bp_triplet_areas =[]

for dcd in dcd_files:
    bp_triplet_areas.append(get_area(dcd, pdb_file, 50, bp_triplet))

# %%
with open('base_triple_area.txt', 'w') as f:
    for force in bp_triplet_areas:
        f.write(f'>{force}\n')
        for dis in bp_triplet_areas[force][0]:
            f.write(str(dis) + '\n')
