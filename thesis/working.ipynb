# %% [markdown]
# # Stuff for the master thesis
# code for generating figures or similiar things for my master thesis

# %%
images_folder = '/scr/aldea/kgutenbrunner/working/thesis/images'

# %%
import random
import RNA

# %% [markdown]
# ## RNA representation

# %%
seq = ''.join(random.choices(list('ACGU'), k = 50))
seq
# Out:
# 'CGCUCCGAGAGAAUUACGCCAUACUCCACACGGCGUACUAGGUACCCUCA'

# %%
for _ in range(10):
    seq = ''.join(random.choices(list('ACGU'), k = 30))
    print(seq)
    print(RNA.fold(seq))
# Out:
# UAGUCUGUAGCCGGUGAGGCUCAGAUUGGA
# ['(((((((.((((.....)))))))))))..', -13.899999618530273]
# CUAUCUUAUCAUCUCACCAGCGGACUCCGU
# ['...................((((...))))', -2.5999999046325684]
# GGACCUCCACUGAAGAAACCCCAGCGCCGC
# ['((....)).(((.........)))......', -1.2999999523162842]
# GGCCGCAGUCGACAUACGUCUCAAACGUGU
# ['(((....)))...((((((.....))))))', -4.599999904632568]
# ACAUUAGAGGGGCAUUUUACUCCUUGGACU
# ['......((((((.......)))))).....', -5.400000095367432]
# AGAUGAGGUAGGUUAUUACCGCGCGCUGCA
# ['......(((((....)))))((.....)).', -4.900000095367432]
# AUGUUAAAGAUCAGCUUUCUUUAGUCAUAG
# ['((((((((((.......))))))).)))..', -5.5]
# UCAUUACUCACCACCUUCUUUAAGCUGUUU
# ['..............................', 0.0]
# CCUUGUACGGGAGAGAGGGAUCCUCAGAAA
# ['(((.....)))...((((...)))).....', -4.800000190734863]
# UUAUAAGAUAGUGGAAUAUAUACUCCCUGU
# ['.......((((.(((........)))))))', -4.599999904632568]

# %%
seq =  'AGCGACAGUAGCCCGAAAGUUCUGAAGUCGUGGAGAAGCA'
ss =  RNA.fold(seq)[0]

# %%
from varnaapi import Structure
import varnaapi
ss =  '..(((.((.....)).)))..(((.((....)))))...'

# %%
seq =  'UAGGUAGGUUAUUACCAAGCGCGCUGCA'
ss =  RNA.fold(seq)[0]
v = varnaapi.Structure(sequence=seq, structure=ss)
# .update(bpStyle='simple', drawBackbone=True, bp='#006400', fillBases=True, spaceBetweenBases=1, resolution=2)

v.update(bpStyle='simple', drawBackbone=True, bp='#006400', fillBases=True, spaceBetweenBases=1, resolution=2)

v.show()
v.savefig('/scr/aldea/kgutenbrunner/working/thesis/images/structure.png')
# Out:
# ['java', '-cp', '/home/mescalin/kgutenbrunner/Downloads/VARNAv3-93.jar', 'fr.orsay.lri.varna.applications.VARNAcmd', '-sequenceDBN', 'UAGGUAGGUUAUUACCAAGCGCGCUGCA', '-structureDBN', '..(((((....)))))..((.....)).', '-o', '/tmp/tmp8u290o0k.png', '-bp', '#006400', '-resolution', '2.0', '-bpStyle', 'simple']
# Output file: /tmp/tmp8u290o0k.png
# ['java', '-cp', '/home/mescalin/kgutenbrunner/Downloads/VARNAv3-93.jar', 'fr.orsay.lri.varna.applications.VARNAcmd', '-sequenceDBN', 'UAGGUAGGUUAUUACCAAGCGCGCUGCA', '-structureDBN', '..(((((....)))))..((.....)).', '-o', '/scr/aldea/kgutenbrunner/working/thesis/images/structure.png', '-bp', '#006400', '-resolution', '2.0', '-bpStyle', 'simple']
# Output file: /scr/aldea/kgutenbrunner/working/thesis/images/structure.png

# %%
# !echo $seq > seq.fa
# !RNAfold -p --MEA < seq.fa
# !convert dot.ps dot.png

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image = mpimg.imread("/scr/aldea/kgutenbrunner/working/thesis/dot.png")
fig, ax = plt.subplots(figsize=(7, 7))
ax.imshow(image)
# !mv /scr/aldea/kgutenbrunner/working/thesis/dot.png /scr/aldea/kgutenbrunner/working/thesis/images/dot.png
# Out:
# UAGGUAGGUUAUUACCAAGCGCGCUGCA
# ..(((((....)))))..((.....)). ( -5.00)
# ..(((((....)))))..((,....)). [ -5.66]
# ..(((((....)))))..((.....)). { -5.00 d=1.83}
# ..(((((....)))))..((.....)). { -5.00 MEA=24.86}
#  frequency of mfe structure in ensemble 0.342227; ensemble diversity 3.02
# WARNING: The convert command is deprecated in IMv7, use "magick"

# %%
def plot_alignment(sequences, names = False, height=None):
    # width = len(sequences)/2)-0.2
    if not height:
        height = len(sequences) /2 + 0.1
    fig, ax = plt.subplots(figsize=(26, height))
    seq_len = len(sequences[0])

    if not names:
        names = [f'Seq{i}' for i in range(len(sequences))]
    for i, seq in enumerate(sequences):
        for j, nt in enumerate(seq):
            ax.text(j-0.25, i-0.15, nt, fontsize=14, color='black', font='monospace', bbox=dict(facecolor=colors[nt], 
            alpha=0.55))
        # ax.text(j*2.45, i, nt, fontsize=14, color='black', font='monospace', bbox=dict(facecolor=colors[nt], alpha=0.5))
    ax.set_yticks(list(range(len(sequences))))

    ax.set_yticklabels(names)
    ax.set_xticks(range(seq_len))
    ax.set_xlim(-1, seq_len)
    ax.set_ylim(-1, len(sequences))
    ax.tick_params(bottom=False, left=False)
    plt.show()

# %%
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)

# %%
def plot_text(text, save):

    fig, ax = plt.subplots(figsize=(10,1))
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)


    for j, nt in enumerate(text):
        ax.text(j*0.035+0.01, 0.3, nt, fontsize=30, color='black', fontname='monospace')

    ax.tick_params(bottom=False, left=False)
    ax.set_facecolor("white")

    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    if save:
        plt.savefig(save)
    else:
        plt.show

plot_text('..(((((....)))))..((.....)).', save='/scr/aldea/kgutenbrunner/working/thesis/images/dotbracket.png')

# %%
# add the pictures together in matplotlib
fig, axs = plt.subplots(1,3, figsize=(12, 12))

for item in [ax]:
    print(item)
    item.patch.set_visible(False)

for i in range(3):
    axs[i].get_xaxis().set_ticks([])
    axs[i].get_yaxis().set_ticks([])
    axs[i].spines['top'].set_visible(False)
    axs[i].spines['right'].set_visible(False)
    axs[i].spines['bottom'].set_visible(False)
    axs[i].spines['left'].set_visible(False)




dotplot_img = mpimg.imread('/scr/aldea/kgutenbrunner/working/thesis/images/dotbracket.png')
axs[0].imshow(dotplot_img)

dotplot_img = mpimg.imread("/scr/aldea/kgutenbrunner/working/thesis/images/RNA_representation_dotpot.png")
axs[1].imshow(dotplot_img)

varnaapi_img = mpimg.imread("/scr/aldea/kgutenbrunner/working/thesis/images/RNA_representation_varnaapi.png")
axs[2].imshow(varnaapi_img)
# Out:
# Axes(0.398529,0.41864;0.227941x0.152721)

# %%
len('UAGGUAGGUUAUUACCAAGCGCGCUGCA') * ' '
# Out:
# '                            '

# %%
import matplotlib.pyplot as plt
import numpy as np

def img_is_color(img):

    if len(img.shape) == 3:
        # Check the color channels to see if they're all the same.
        c1, c2, c3 = img[:, : , 0], img[:, :, 1], img[:, :, 2]
        if (c1 == c2).all() and (c2 == c3).all():
            return True

    return False

def show_image_list(list_images, list_titles=None, list_cmaps=None, grid=True, num_cols=2, figsize=(20, 10), title_fontsize=30):
    '''
    Shows a grid of images, where each image is a Numpy array. The images can be either
    RGB or grayscale.

    Parameters:
    ----------
    images: list
        List of the images to be displayed.
    list_titles: list or None
        Optional list of titles to be shown for each image.
    list_cmaps: list or None
        Optional list of cmap values for each image. If None, then cmap will be
        automatically inferred.
    grid: boolean
        If True, show a grid over each image
    num_cols: int
        Number of columns to show.
    figsize: tuple of width, height
        Value to be passed to pyplot.figure()
    title_fontsize: int
        Value to be passed to set_title().
    '''

    assert isinstance(list_images, list)
    assert len(list_images) > 0
    assert isinstance(list_images[0], np.ndarray)

    if list_titles is not None:
        assert isinstance(list_titles, list)
        assert len(list_images) == len(list_titles), '%d imgs != %d titles' % (len(list_images), len(list_titles))

    if list_cmaps is not None:
        assert isinstance(list_cmaps, list)
        assert len(list_images) == len(list_cmaps), '%d imgs != %d cmaps' % (len(list_images), len(list_cmaps))

    num_images  = len(list_images)
    num_cols    = min(num_images, num_cols)
    num_rows    = int(num_images / num_cols) + (1 if num_images % num_cols != 0 else 0)

    # Create a grid of subplots.
    fig, axes = plt.subplots(num_rows, num_cols, figsize=figsize)
    
    # Create list of axes for easy iteration.
    if isinstance(axes, np.ndarray):
        list_axes = list(axes.flat)
    else:
        list_axes = [axes]

    for i in range(num_images):

        img    = list_images[i]
        title  = list_titles[i] if list_titles is not None else 'Image %d' % (i)
        cmap   = list_cmaps[i] if list_cmaps is not None else (None if img_is_color(img) else 'gray')
        
        list_axes[i].imshow(img, cmap=cmap)
        list_axes[i].set_title(title, fontsize=title_fontsize) 
        list_axes[i].grid(grid)

    for i in range(num_images, len(list_axes)):
        list_axes[i].set_visible(False)

    fig.tight_layout()
    _ = plt.show()

# %%
show_image_list(imgs, list_titles=['b)', 'c)'], figsize=(10, 10), grid=False)

# %% [markdown]
# ## example structure for MBFV and TBFV

# %%
DTV_seq = 'ACAGGGGGUGAUGUGGCAGCGCACCACGACAUCGUGACGGGAAGAGGUCGUCCCCGACGCAUCAUCUCUCUAGGGCAUUUUCGUGAGACCCUCAU'
DTV_ss =  '...((((((((((((...[[[(((.........)))..(((..{{{{..{{{)))..))))))))))))............]]]..}}}}}}}..'

# %%
seq = DTV_seq
ss = DTV_ss
v = varnaapi.Structure(sequence=seq, structure=ss)
# .update(bpStyle='simple', drawBackbone=True, bp='#006400', fillBases=True, spaceBetweenBases=1, resolution=2)

v.update(bpStyle='simple', drawBackbone=True, bp='#006400', fillBases=True, spaceBetweenBases=1, resolution=2)

v.show()
v.savefig('/scr/aldea/kgutenbrunner/working/thesis/images/structure.png')
# Out:
# ['java', '-cp', '/home/mescalin/kgutenbrunner/Downloads/VARNAv3-93.jar', 'fr.orsay.lri.varna.applications.VARNAcmd', '-sequenceDBN', 'ACAGGGGGUGAUGUGGCAGCGCACCACGACAUCGUGACGGGAAGAGGUCGUCCCCGACGCAUCAUCUCUCUAGGGCAUUUUCGUGAGACCCUCAU', '-structureDBN', '...((((((((((((...[[[(((.........)))..(((..{{{{..{{{)))..))))))))))))............]]]..}}}}}}}..', '-o', '/tmp/tmpkpxsoeng.png', '-bp', '#006400', '-resolution', '2.0', '-bpStyle', 'simple']
# Output file: /tmp/tmpkpxsoeng.png
# ['java', '-cp', '/home/mescalin/kgutenbrunner/Downloads/VARNAv3-93.jar', 'fr.orsay.lri.varna.applications.VARNAcmd', '-sequenceDBN', 'ACAGGGGGUGAUGUGGCAGCGCACCACGACAUCGUGACGGGAAGAGGUCGUCCCCGACGCAUCAUCUCUCUAGGGCAUUUUCGUGAGACCCUCAU', '-structureDBN', '...((((((((((((...[[[(((.........)))..(((..{{{{..{{{)))..))))))))))))............]]]..}}}}}}}..', '-o', '/scr/aldea/kgutenbrunner/working/thesis/images/structure.png', '-bp', '#006400', '-resolution', '2.0', '-bpStyle', 'simple']
# Output file: /scr/aldea/kgutenbrunner/working/thesis/images/structure.png

# %% [markdown]
# # xrRNA analysis plots

# %% [markdown]
# ## MBFV

# %%
import os
import csv
import re
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# left YVf out since it has a really big hl beta --> outlier
# also stems are counting as base pairs not nts
stats= '/scr/aldea/kgutenbrunner/working/xrRNA_design/analysis_MBFV/data/MBFW_xrRNA1.txt'
df = pd.read_csv(stats, delimiter=",")
df = df.drop(columns=['seq_ML', 'seq_PKA', 'seq_PKB'])
# add stem structure together for further analysis
df_nts = df.copy()
temp_df = df_nts.drop(columns='name').astype(int)
df_nts['alpha'] = temp_df['stemA']*2
df_nts['beta'] = temp_df['stemB']*2 + temp_df['hlB']
df_nts['gamma'] = temp_df['stemG']*2 + temp_df['hlG']
df_nts['stemG'] = temp_df['stemG']*2
df_nts['stemB'] = temp_df['stemB']*2
df_nts['stemA'] = temp_df['stemA']*2

df_nts['n_PK'] = temp_df['n_PK']*2
# df_merge = df_merge[['name', 'I', 'II', 'III', 'HL', 'sum']]
new_order = ['name', 'stemA', 'alpha', 'stemB', 'hlB', 'beta', 'stemG','hlG','gamma', 'n_PK','bPK','b_PK','a_PK']
df_nts = df_nts[new_order]
df_nts
# Out:
#       name  stemA  alpha  stemB  hlB  beta  stemG  hlG  gamma  n_PK  bPK  \
# 0   AROAVG     10     10      4    4     8     10   12     22    12    2
# 1     BAGV     10     10     10    5    15     10   12     22    16    0
# 2     BANV     10     10      4    5     9     14    9     23    10    3
# 3    DENV1     10     10      2    7     9     12    9     21     8    6
# 4    DENV2     10     10      2    7     9     12    9     21     8    6
# 5    DENV3     10     10      2    7     9     12    9     21     6    6
# 6    DENV4     10     10      4    4     8     10   10     20     8    2
# 7      JEV     10     10      8    4    12     10   13     23    14    0
# 8     KOKV     10     10      4    4     8     10   10     20    12    0
# 9     KOUV     10     10      6    6    12     10   13     23    12    3
# 10    KUNV     10     10      6    7    13     10   13     23    16    0
# 11    MVEV     10     10     10    5    15     10   12     22    16    0
# 12     NMV     10     10      2    5     7     10   10     20    10    2
# 13    SLEV     10     10      6    6    12     10   13     23    14    2
# 14    TMUV     10     10     10    3    13     10   12     22    12    0
# 15    UGSV     10     10      6    3     9      8   15     23     8    0
# 16    USUV     10     10      8    4    12     10   13     23    16    0
# 17   WESSV     10     10      8    4    12     12   11     23    10    2
# 18     WNV     10     10     10    3    13     10   13     23    16    0
# 19    ZIKV     10     10      6    5    11     16    5     21     8    4
#
#     b_PK  a_PK
# 0      3     3
# 1      3     1
# 2      1     3
# 3      0     5
# 4      0     5
# 5      1     5
# 6      3     3
# 7      3     1
# 8      3     1
# 9      3     4
# 10     3     1
# 11     2     1
# 12     3     2
# 13     3     3
# 14     5     1
# 15     7     3
# 16     3     1
# 17     3     3
# 18     3     1
# 19     0     1

# %%
plt.rcParams['text.usetex'] = True

temp_df = df_nts.drop(columns=['name']).astype(int)
plt.figure(figsize=(10, 10))
temp_df.boxplot()
plt.title('MBFV xrRNA length analysis')

labels = [r'stem $\alpha$', r'$\alpha$', r'stem $\beta$', r'hl $\beta$', r'$\beta$', r'stem $\gamma$', r'hl $\gamma$', r'$\gamma$', 'PK2', 'until PK2', 'before PK2', 'after PK2']
plt.xticks(list(range(1, len(labels)+1)), labels, rotation=45)
plt.yticks(np.arange(0, 24, step=2))
#plt.xticklabels([r'$\frac{1}/{2}$', ''])
#plt.savefig('/scr/aldea/kgutenbrunner/working/thesis/images/xrRNA_analysis_boxplot.png')
# Out:
# ([<matplotlib.axis.YTick at 0x7fc1ac636630>,
#   <matplotlib.axis.YTick at 0x7fc1ac6353a0>,
#   <matplotlib.axis.YTick at 0x7fc1ac813380>,
#   <matplotlib.axis.YTick at 0x7fc1ac515df0>,
#   <matplotlib.axis.YTick at 0x7fc1ac516750>,
#   <matplotlib.axis.YTick at 0x7fc1ac5170e0>,
#   <matplotlib.axis.YTick at 0x7fc1ac516960>,
#   <matplotlib.axis.YTick at 0x7fc1ac517590>,
#   <matplotlib.axis.YTick at 0x7fc1ac517ef0>,
#   <matplotlib.axis.YTick at 0x7fc1ac5287a0>,
#   <matplotlib.axis.YTick at 0x7fc1ac529100>,
#   <matplotlib.axis.YTick at 0x7fc1ac6ecec0>],
#  [Text(0, 0, '$\\mathdefault{0}$'),
#   Text(0, 2, '$\\mathdefault{2}$'),
#   Text(0, 4, '$\\mathdefault{4}$'),
#   Text(0, 6, '$\\mathdefault{6}$'),
#   Text(0, 8, '$\\mathdefault{8}$'),
#   Text(0, 10, '$\\mathdefault{10}$'),
#   Text(0, 12, '$\\mathdefault{12}$'),
#   Text(0, 14, '$\\mathdefault{14}$'),
#   Text(0, 16, '$\\mathdefault{16}$'),
#   Text(0, 18, '$\\mathdefault{18}$'),
#   Text(0, 20, '$\\mathdefault{20}$'),
#   Text(0, 22, '$\\mathdefault{22}$')])

# %%
import matplotlib.pyplot as plt


def correlation_analysis(df, method = 'spearman', statistic_file = False, save_fig = False, labels = None, mask = True):
    stats_df = df.drop(columns='name').astype(int)
    #create some correlation analysis
    corr =  stats_df.corr(method=method, numeric_only=False)
    
    # Display the correlation matrix
    if mask:
        mask = np.zeros_like(corr, dtype=bool)
        mask[np.triu_indices_from(mask)] = True
        corr[mask] = np.nan
    #print(round(corr, 2))
    if statistic_file:
        corr.to_csv(statistic_file)
    plt.figure(figsize=(10, 10))
    
    plt.imshow(corr, cmap='coolwarm', interpolation='nearest', vmin=-1, vmax=1,)
    plt.colorbar(label=f'Correlation')

    plt.title(f'Correlation Heatmap by {method}')
    if labels:
        plt.xticks(np.arange(len(corr)), labels, rotation=45)
        plt.yticks(np.arange(len(corr)), labels)
    else:
        plt.xticks(np.arange(len(corr)), corr.columns, rotation=45)
        plt.yticks(np.arange(len(corr)), corr.columns)
        
    if save_fig:
        plt.savefig(save_fig)
    else:
        plt.show()
    return corr

# %%
temp_df = df_nts.drop(columns=['stemA', 'alpha', 'bPK', 'a_PK', 'b_PK'])

labels = [r'stem $\beta$', r'hl $\beta$', r'$\beta$', r'stem $\gamma$', r'hl $\gamma$', r'$\gamma$', 'PK2']

correlation_analysis(temp_df, method="spearman", labels=labels, mask = True, save_fig='/scr/aldea/kgutenbrunner/working/thesis/images/xrRNA_analysis_correlation.png')
# Out:
#           stemB       hlB      beta     stemG       hlG     gamma  n_PK
# stemB       NaN       NaN       NaN       NaN       NaN       NaN   NaN
# hlB   -0.508685       NaN       NaN       NaN       NaN       NaN   NaN
# beta   0.859603 -0.033059       NaN       NaN       NaN       NaN   NaN
# stemG -0.375293  0.481083 -0.159041       NaN       NaN       NaN   NaN
# hlG    0.590892 -0.387597  0.480411 -0.814203       NaN       NaN   NaN
# gamma  0.553985 -0.188148  0.564667 -0.223045  0.718786       NaN   NaN
# n_PK   0.715406 -0.196848  0.696403 -0.493642  0.648469  0.497684   NaN

# %% [markdown]
# ## TBFV

# %%
import os
import re
import pandas as pd
import numpy as np

stats= '/scr/aldea/kgutenbrunner/working/xrRNA_design/analysis_TBFV/data/TBFV_ss.csv'
df = pd.read_csv(stats, skiprows=13, delimiter=";")

# %%
#only want xrRNA1
xrRNA1_df = df[df['xrRNA-no'] == 1]
#only want samples with both pseudoknots
xrRNA1_df_clean = xrRNA1_df[xrRNA1_df['PKs?'] == '1+2']
xrRNA1_df_clean = xrRNA1_df_clean.drop(columns=['PKs?', 'xrRNA-no', 'numSeqs'])

#only want samples with all 3 stems
xrRNA1_df_clean = xrRNA1_df_clean[xrRNA1_df_clean['ML-I/III'] == "-"]
xrRNA1_df_clean = xrRNA1_df_clean.drop(columns=['ML-I/III'])


#remove columns which have only 0s / -
col_no_values = xrRNA1_df_clean.columns[(xrRNA1_df_clean == "-").all()]
xrRNA1_df_clean = xrRNA1_df_clean.drop(columns=col_no_values)

#remove columns which have only 0s / -
same_value_columns = xrRNA1_df_clean.columns[xrRNA1_df_clean.nunique() == 1]
xrRNA1_df_clean = xrRNA1_df_clean.drop(columns=same_value_columns)

# change - to 0s
xrRNA1_df_clean = xrRNA1_df_clean.replace('-', 0)

# add Interloop 1 add up, (have some with 2 loops, add to one)
xrRNA1_df_clean = xrRNA1_df_clean.replace('2+2', 4)

temp_df = xrRNA1_df_clean.drop(columns='name').astype(int)

#double the nucleotides in Stems because we counted basepairs not nucleotides
xrRNA1_df_clean['ST-I'] = temp_df['ST-I'] * 2
xrRNA1_df_clean['ST-II'] = temp_df['ST-II'] * 2
xrRNA1_df_clean['ST-III'] = temp_df['ST-III'] * 2


xrRNA1_df_clean['I'] = temp_df['ST-I'] *2 + temp_df['IL-I'] + temp_df['BL-I']
xrRNA1_df_clean['II'] = temp_df['ST-II'] *2 + temp_df['HL-II'] + temp_df['BL-II']
xrRNA1_df_clean['III'] = temp_df['ST-III'] *2 + temp_df['HL-III']

xrRNA1_df_clean = xrRNA1_df_clean.drop(columns=['BL-I', 'BL-II'])

# %%
xrRNA1_df_clean
# Out:
#     name  ST-I IL-I  ST-II HL-II  ST-III  HL-III  uPK1 PK1bPK2   I  II  III
# 0   ALKV    22    4      8     4      10      10     8       0  26  12   20
# 1    DTV    24    0      6     9       8      11    12       2  24  15   19
# 3    GGV    24    0      6     7      14       4    15       2  24  14   18
# 5   KFDV    24    2      8     4      10      10     8       2  26  12   20
# 6   KSIV    28    2      8     3       8      12     8       2  30  11   20
# 8   LGTV    24    4     10     3      10      10    11       0  28  13   20
# 10   LIV    24    2      6     4       8      12    11       0  27  10   20
# 15  NEGV    26    0      6     4       8      12    11       0  27  10   20
# 17  OHFV    24    2      6     4       8      12    11       0  28  10   20
# 19  POWV    24    0      6     9       8      11    14       2  24  15   19
# 21  SGEV    26    2      6     4       8      12    10       0  29  10   20
# 24  TBEV    22    4      6     4       8      12    11       0  27  10   20

# %%
pk_stats = '/scr/aldea/kgutenbrunner/working/xrRNA_design/analysis_TBFV/data/pk2_stats.txt'
df_pk = pd.read_csv(pk_stats, skiprows=1, delimiter=", ")
# df_pk = df_pk.drop([2])
df_pk = df_pk.drop(columns=['posA', 'posB', 'total'])

df_pk['nt'] = df_pk['nt'] * 2

df_pk
# Out:
# /tmp/ipykernel_3259345/3250634261.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df_pk = pd.read_csv(pk_stats, skiprows=1, delimiter=", ")
#     name  until  nt  after
# 0   ALKV      3  12      0
# 1    DTV      2  14      0
# 2    GGV      0   8      0
# 3   KFDV      4  10      2
# 4   KSIV      5   8      3
# 5   LGTV      4  10      0
# 6    LIV      5  10      1
# 7   NEGV      5  10      1
# 8   OHFV      5  10      1
# 9   POWV      4   8      3
# 10  SGEV      5  10      1
# 11  TBEV      5  10      1

# %%
df_nts = pd.merge(xrRNA1_df_clean, df_pk)
df_nts
# Out:
#     name  ST-I IL-I  ST-II HL-II  ST-III  HL-III  uPK1 PK1bPK2   I  II  III  \
# 0   ALKV    22    4      8     4      10      10     8       0  26  12   20
# 1    DTV    24    0      6     9       8      11    12       2  24  15   19
# 2    GGV    24    0      6     7      14       4    15       2  24  14   18
# 3   KFDV    24    2      8     4      10      10     8       2  26  12   20
# 4   KSIV    28    2      8     3       8      12     8       2  30  11   20
# 5   LGTV    24    4     10     3      10      10    11       0  28  13   20
# 6    LIV    24    2      6     4       8      12    11       0  27  10   20
# 7   NEGV    26    0      6     4       8      12    11       0  27  10   20
# 8   OHFV    24    2      6     4       8      12    11       0  28  10   20
# 9   POWV    24    0      6     9       8      11    14       2  24  15   19
# 10  SGEV    26    2      6     4       8      12    10       0  29  10   20
# 11  TBEV    22    4      6     4       8      12    11       0  27  10   20
#
#     until  nt  after
# 0       3  12      0
# 1       2  14      0
# 2       0   8      0
# 3       4  10      2
# 4       5   8      3
# 5       4  10      0
# 6       5  10      1
# 7       5  10      1
# 8       5  10      1
# 9       4   8      3
# 10      5  10      1
# 11      5  10      1

# %%
new_order = ['name', 'ST-I', 'IL-I', 'I', 'ST-II', 'HL-II', 'II', 'ST-III', 'HL-III', 'III', 'nt', 'until', 'after','uPK1','PK1bPK2']
df_nts = df_nts[new_order]

print(df_nts)
# Out:
#     name  ST-I IL-I   I  ST-II HL-II  II  ST-III  HL-III  III  nt  until  \
# 0   ALKV    22    4  26      8     4  12      10      10   20  12      3
# 1    DTV    24    0  24      6     9  15       8      11   19  14      2
# 2    GGV    24    0  24      6     7  14      14       4   18   8      0
# 3   KFDV    24    2  26      8     4  12      10      10   20  10      4
# 4   KSIV    28    2  30      8     3  11       8      12   20   8      5
# 5   LGTV    24    4  28     10     3  13      10      10   20  10      4
# 6    LIV    24    2  27      6     4  10       8      12   20  10      5
# 7   NEGV    26    0  27      6     4  10       8      12   20  10      5
# 8   OHFV    24    2  28      6     4  10       8      12   20  10      5
# 9   POWV    24    0  24      6     9  15       8      11   19   8      4
# 10  SGEV    26    2  29      6     4  10       8      12   20  10      5
# 11  TBEV    22    4  27      6     4  10       8      12   20  10      5
#
#     after  uPK1 PK1bPK2
# 0       0     8       0
# 1       0    12       2
# 2       0    15       2
# 3       2     8       2
# 4       3     8       2
# 5       0    11       0
# 6       1    11       0
# 7       1    11       0
# 8       1    11       0
# 9       3    14       2
# 10      1    10       0
# 11      1    11       0

# %%
import matplotlib.pyplot as plt


def correlation_analysis(df, method = 'spearman', statistic_file = False, save_fig = False, labels = None, mask = True):
    stats_df = df.drop(columns='name').astype(int)
    #create some correlation analysis
    corr =  stats_df.corr(method=method, numeric_only=False)
    
    # Display the correlation matrix
    if mask:
        mask = np.zeros_like(corr, dtype=bool)
        mask[np.triu_indices_from(mask)] = True
        corr[mask] = np.nan
    #print(round(corr, 2))
    if statistic_file:
        corr.to_csv(statistic_file)
    plt.figure(figsize=(10, 10))
    
    plt.imshow(corr, cmap='coolwarm', interpolation='nearest', vmin=-1, vmax=1,)
    plt.colorbar(label=f'Correlation')

    plt.title(f'Correlation Heatmap by {method}')
    if labels:
        plt.xticks(np.arange(len(corr)), labels, rotation=45)
        plt.yticks(np.arange(len(corr)), labels)
    else:
        plt.xticks(np.arange(len(corr)), corr.columns, rotation=45)
        plt.yticks(np.arange(len(corr)), corr.columns)
        
    if save_fig:
        plt.savefig(save_fig)
    else:
        plt.show()
    return corr

# %%
# new_order = ['ST-I', 'IL-I', 'I', 'ST-II', 'HL-II', 'II', 'III','ST-III', 'HL-III', 'nt', 'until', 'after','uPK1','PK1bPK2']
temp_df = df_nts.drop(columns=['until', 'after', 'uPK1', 'PK1bPK2'])

labels = [r'Stem $\alpha$', r'IL $\beta$', r'$\alpha$', r'Stem $\beta$', r'HL $\beta$', r'$\beta$', r'Stem $\gamma$', r'HL $\gamma$', r'$\gamma$', 'PK2']

correlation_analysis(temp_df, method="spearman", mask = True,labels=labels) # , save_fig='/scr/aldea/kgutenbrunner/working/thesis/images/xrRNA_analysis_correlation.png'
# Out:
#             ST-I      IL-I         I     ST-II     HL-II        II    ST-III  \
# ST-I         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# IL-I   -0.444306       NaN       NaN       NaN       NaN       NaN       NaN
# I       0.496304  0.489142       NaN       NaN       NaN       NaN       NaN
# ST-II  -0.035299  0.573030  0.263080       NaN       NaN       NaN       NaN
# HL-II  -0.263158 -0.688361 -0.843118 -0.663619       NaN       NaN       NaN
# II     -0.189532 -0.348932 -0.677945  0.236189  0.489116       NaN       NaN
# ST-III -0.345929  0.199217 -0.335801  0.542929 -0.063538  0.446134       NaN
# HL-III  0.399022  0.034139  0.619798 -0.437247 -0.259681 -0.776955 -0.897150
# III     0.092803  0.706188  0.759134  0.398344 -0.819762 -0.761821 -0.182574
# nt     -0.396480  0.297512 -0.104103  0.061455  0.048459 -0.090067 -0.033091
#
#           HL-III       III  nt
# ST-I         NaN       NaN NaN
# IL-I         NaN       NaN NaN
# I            NaN       NaN NaN
# ST-II        NaN       NaN NaN
# HL-II        NaN       NaN NaN
# II           NaN       NaN NaN
# ST-III       NaN       NaN NaN
# HL-III       NaN       NaN NaN
# III     0.491389       NaN NaN
# nt     -0.012723  0.269282 NaN

# %%
df_nts
# Out:
#     name  ST-I IL-I   I  ST-II HL-II  II  ST-III  HL-III  III  nt  until  \
# 0   ALKV    22    4  26      8     4  12      10      10   20  12      3
# 1    DTV    24    0  24      6     9  15       8      11   19  14      2
# 2    GGV    24    0  24      6     7  14      14       4   18   8      0
# 3   KFDV    24    2  26      8     4  12      10      10   20  10      4
# 4   KSIV    28    2  30      8     3  11       8      12   20   8      5
# 5   LGTV    24    4  28     10     3  13      10      10   20  10      4
# 6    LIV    24    2  27      6     4  10       8      12   20  10      5
# 7   NEGV    26    0  27      6     4  10       8      12   20  10      5
# 8   OHFV    24    2  28      6     4  10       8      12   20  10      5
# 9   POWV    24    0  24      6     9  15       8      11   19   8      4
# 10  SGEV    26    2  29      6     4  10       8      12   20  10      5
# 11  TBEV    22    4  27      6     4  10       8      12   20  10      5
#
#     after  uPK1 PK1bPK2
# 0       0     8       0
# 1       0    12       2
# 2       0    15       2
# 3       2     8       2
# 4       3     8       2
# 5       0    11       0
# 6       1    11       0
# 7       1    11       0
# 8       1    11       0
# 9       3    14       2
# 10      1    10       0
# 11      1    11       0

# %%
plt.rcParams['text.usetex'] = True

temp_df = df_nts.drop(columns=['name']).astype(int)
plt.figure(figsize=(10, 10))
temp_df.boxplot()
plt.title('MBFV xrRNA length analysis')

new_order = ['name', 'ST-I', 'IL-I', 'I', 'ST-II', 'HL-II', 'II', 'ST-III', 'HL-III', 'III', 'nt', 'until', 'after','uPK1','PK1bPK2']

labels = [r'Stem $\alpha$', r'IL $\beta$', r'$\alpha$', r'Stem $\beta$', r'HL $\beta$', r'$\beta$', r'Stem $\gamma$', r'HL $\gamma$', r'$\gamma$', 'PK2', 'until PK2', 'after PK2', 'until PK1', 'btw. PK1 PK2']

plt.xticks(list(range(1, len(labels)+1)), labels, rotation=45)

plt.yticks(np.arange(0, 34, step=2))
#plt.xticklabels([r'$\frac{1}/{2}$', ''])
#plt.savefig('/scr/aldea/kgutenbrunner/working/thesis/images/xrRNA_analysis_boxplot.png')
plt.show()
